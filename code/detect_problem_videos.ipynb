# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mkdir /content/results2020

# %%
# %cd /content/drive/MyDrive/projects/pose_detection/videos/2020
# Out:
# /content/drive/MyDrive/projects/pose_detection/videos/2020

# %%
# !for i in *.wmv; do ffmpeg -i "$i" -vf mpdecimate -loglevel debug -f null - 2>"/content/results2020/${i%.*}.txt"; done

# %%
# !zip -r /content/2020.zip /content/results2020
# Out:
#   adding: content/results2020/ (stored 0%)
#   adding: content/results2020/USSEN_GA_LOEFFLER_PROPAGANDA.txt (deflated 89%)
#   adding: content/results2020/USSEN_AZ_KELLY_THE_JOURNEY_60.txt (deflated 88%)
#   adding: content/results2020/HOUSE_VA07_SPANBERGER_ALWAYS_WANTED_TO_BE_CIA.txt (deflated 89%)
#   adding: content/results2020/USSEN_MT_DAINES_ACCOUNTABLE_3.txt (deflated 88%)
#   adding: content/results2020/HOUSE_NY25_MORELLE_TIMES_LIKE_THESE.txt (deflated 87%)
#   adding: content/results2020/HOUSE_CA24_CALDWELL_NO_POLITICIAN.txt (deflated 87%)
#   adding: content/results2020/USSEN_IA_GREENFIELD_GOOD_HEALTHCARE.txt (deflated 88%)
#   adding: content/results2020/STSEN_FL_EDDEN_I_HAVE_BEEN_ADVOCATING_FOR_CHANGE.txt (deflated 87%)
#   adding: content/results2020/STREP_TX_BUCKLEY_KNOWS_HOW_TO_KEEP_OUR_COMMUNITY.txt (deflated 89%)
#   adding: content/results2020/HOUSE_FL26_GIMENEZ_GET_RESULTS.txt (deflated 87%)
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !mkdir /content/results2018

# %%
# %cd /content/drive/MyDrive/projects/pose_detection/videos/2018
# Out:
# /content/drive/MyDrive/projects/pose_detection/videos/2018

# %%
# !for i in *.wmv; do ffmpeg -i "$i" -vf mpdecimate -loglevel debug -f null - 2>"/content/results2018/${i%.*}.txt"; done

# %%
# !zip -r /content/2018.zip /content/results2018
# Out:
#   adding: content/results2018/ (stored 0%)
#   adding: content/results2018/HOUSE_GA06_GRAY_AMERICAN_DREAM.txt (deflated 91%)
#   adding: content/results2018/GOV_TN_BOYD_HUCKABEE_ENDORSEMENT.txt (deflated 89%)
#   adding: content/results2018/GOV_SC_WILLIS_WHY_I_M_RUNNING.txt (deflated 88%)
#   adding: content/results2018/GOV_NV_SCHWARTZ_1776_15.txt (deflated 86%)
#   adding: content/results2018/HOUSE_IA03_AXNE_FIGHT_FOR_WHAT_S_RIGHT.txt (deflated 87%)
#   adding: content/results2018/HOUSE_PA08_KUNIEGEL_WOULDN_T_IT_BE_NICE.txt (deflated 86%)
#   adding: content/results2018/GOV_IL_PRITZKER_MK.txt (deflated 91%)
#   adding: content/results2018/HOUSE_GA06_OSSOFF_I_GREW_UP_HERE.txt (deflated 91%)
#   adding: content/results2018/USSEN_MI_STABENOW_GREAT_LAKES.txt (deflated 88%)
#   adding: content/results2018/HOUSE_TX27_PEREZ_WITHOUT_A_VOICE.txt (deflated 88%)
#   adding: content/results2018/USSEN_MI_STABENOW_BEHIND_YOU.txt (deflated 88%)
# ...
